# %%
using PyPlot

grid=linspace(-2pi,2pi,11)

vals=tan(grid)




grid=[-pi,pi]
vals=tan(grid)
plot(grid,vals)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x3218163c8>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x3225e5860>
